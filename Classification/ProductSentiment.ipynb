# %%
import turicreate
products = turicreate.SFrame('/content/drive/My Drive/Colab Notebooks/Coursera/Classification/amazonbaby_frame/m_bfaa91c17752f745.frame_idx')

# %%
products.head()

# %%
products['word_count'] = turicreate.text_analytics.count_words(products['review'])

# %%
giraffe_review = products[products['name']=='Vulli Sophie the Giraffe Teether']

# %%
giraffe_review['rating'].show()
products['rating'].show()

# %%
products = products[products['rating']!=3]

# %%
products['sentiment'] = products['rating']>=4

# %%
train_data, test_data = products.random_split(.8,seed=0)
sentiment_model = turicreate.logistic_classifier.create(train_data, target='sentiment', features=['word_count'],validation_set=test_data)
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 133448
# Number of classes           : 2
# Number of feature columns   : 1
# Number of unpacked features : 57356
# Number of coefficients      : 57357
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+---------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training Accuracy | Validation Accuracy |
# +-----------+----------+-----------+--------------+-------------------+---------------------+
# | 0         | 4        | 0.250000  | 2.516622     | 0.841421          | 0.840019            |
# | 1         | 9        | 3.250000  | 4.708156     | 0.931359          | 0.911362            |
# | 2         | 11       | 2.669978  | 5.782506     | 0.938650          | 0.916466            |
# ...

# %%
sentiment_model.evaluate(test_data)

# %%
giraffe_review['predicted_sentiment'] = sentiment_model.predict(giraffe_review, output_type='probability')

# %%
giraffe_review = giraffe_review.sort('predicted_sentiment',ascending=False)

# %%
giraffe_review.head()
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	predicted_sentiment	float
#
# Rows: 10
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# | Vulli Sophie the Giraffe T... | I'll be honest...I bought ... |  4.0   |
# | Vulli Sophie the Giraffe T... | As a mother of 16month old... |  5.0   |
# | Vulli Sophie the Giraffe T... | Sophie, oh Sophie, your ti... |  5.0   |
# | Vulli Sophie the Giraffe T... | We got this little giraffe... |  5.0   |
# | Vulli Sophie the Giraffe T... | As every mom knows, you al... |  5.0   |
# | Vulli Sophie the Giraffe T... | My Mom-in-Law bought Sophi... |  5.0   |
# | Vulli Sophie the Giraffe T... | My 4 month old son is teet... |  4.0   |
# | Vulli Sophie the Giraffe T... | Let me just start off by a... |  5.0   |
# ...
