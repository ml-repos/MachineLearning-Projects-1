# %%
import turicreate
songdata = turicreate.SFrame('/content/drive/My Drive/Colab Notebooks/Coursera/Recommand System/song_data.sframe/m_cccc16853452d1ed.frame_idx')

# %%
# songdata.head()
users = songdata['user_id'].unique()

# %%
train_data, test_data = songdata.random_split(.8,seed=0)

# %%
popularity_model = turicreate.popularity_recommender.create(train_data,user_id='user_id',item_id='song')
# Out:
# Warning: Ignoring columns song_id, listen_count, title, artist;
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 1.39077s
# 893580 observations to process; with 9952 unique items.

# %%
popularity_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+--------+------+
# |            user_id            |              song              | score  | rank |
# +-------------------------------+--------------------------------+--------+------+
# | c66c10a9567f0d82ff31441a9f... |    Sehr kosmisch - Harmonia    | 4754.0 |  1   |
# | c66c10a9567f0d82ff31441a9f... |          Undo - Björk          | 4227.0 |  2   |
# | c66c10a9567f0d82ff31441a9f... | You're The One - Dwight Yoakam | 3781.0 |  3   |
# | c66c10a9567f0d82ff31441a9f... | Dog Days Are Over (Radio E...  | 3633.0 |  4   |
# | c66c10a9567f0d82ff31441a9f... |    Revelry - Kings Of Leon     | 3527.0 |  5   |
# | c66c10a9567f0d82ff31441a9f... | Horn Concerto No. 4 in E f...  | 3161.0 |  6   |
# | c66c10a9567f0d82ff31441a9f... |     Secrets - OneRepublic      | 3148.0 |  7   |
# | c66c10a9567f0d82ff31441a9f... | Fireflies - Charttraxx Karaoke | 2532.0 |  8   |
# | c66c10a9567f0d82ff31441a9f... |       Tive Sim - Cartola       | 2521.0 |  9   |
# | c66c10a9567f0d82ff31441a9f... | Drop The World - Lil Wayne...  | 2053.0 |  10  |
# +-------------------------------+--------------------------------+--------+------+
# [10 rows x 4 columns]

# %%
personalized_model = turicreate.item_similarity_recommender.create(train_data,user_id='user_id',item_id='song')
# Out:
# Warning: Ignoring columns song_id, listen_count, title, artist;
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 1.52929s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.548ms                        | 1.5        |
# | 59.269ms                       | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 486.021ms                           | 0                | 0               |
# | 2.17s                               | 100              | 9952            |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 3.2556s

# %%
personalized_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |            user_id            |              song              |
# +-------------------------------+--------------------------------+
# | c66c10a9567f0d82ff31441a9f... | Cuando Pase El Temblor - S...  |
# | c66c10a9567f0d82ff31441a9f... | Fireflies - Charttraxx Karaoke |
# | c66c10a9567f0d82ff31441a9f... | Love Is A Losing Game - Am...  |
# | c66c10a9567f0d82ff31441a9f... |        Marry Me - Train        |
# | c66c10a9567f0d82ff31441a9f... |     Secrets - OneRepublic      |
# | c66c10a9567f0d82ff31441a9f... |    Sehr kosmisch - Harmonia    |
# | c66c10a9567f0d82ff31441a9f... | Te Hacen Falta Vitaminas -...  |
# | c66c10a9567f0d82ff31441a9f... | OMG - Usher featuring will...  |
# | c66c10a9567f0d82ff31441a9f... | Y solo se me ocurre amarte...  |
# | c66c10a9567f0d82ff31441a9f... |   No Dejes Que... - Caifanes   |
# +-------------------------------+--------------------------------+
# +----------------------+------+
# |        score         | rank |
# +----------------------+------+
# | 0.019450453611520622 |  1   |
# | 0.014473731701190654 |  2   |
# | 0.014286596041459303 |  3   |
# | 0.014133471709031325 |  4   |
# | 0.013591665488023024 |  5   |
# | 0.013398789442502536 |  6   |
# | 0.01293028317964994  |  7   |
# | 0.012777828253232516 |  8   |
# | 0.012341127945826603 |  9   |
# | 0.012104249917543851 |  10  |
# +----------------------+------+
# [10 rows x 4 columns]

# %%
personalized_model.get_similar_items(['With Or Without You - U2'])
# Out:
# Columns:
# 	song	str
# 	similar	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +--------------------------+-------------------------------+
# |           song           |            similar            |
# +--------------------------+-------------------------------+
# | With Or Without You - U2 | I Still Haven't Found What... |
# | With Or Without You - U2 | Hold Me_ Thrill Me_ Kiss M... |
# | With Or Without You - U2 |    Window In The Skies - U2   |
# | With Or Without You - U2 |          Vertigo - U2         |
# | With Or Without You - U2 |   Sunday Bloody Sunday - U2   |
# | With Or Without You - U2 |            Bad - U2           |
# | With Or Without You - U2 |     A Day Without Me - U2     |
# | With Or Without You - U2 | Another Time Another Place... |
# | With Or Without You - U2 |          Walk On - U2         |
# | With Or Without You - U2 |     Get On Your Boots - U2    |
# +--------------------------+-------------------------------+
# +----------------------+------+
# |        score         | rank |
# +----------------------+------+
# | 0.04285717010498047  |  1   |
# | 0.033734917640686035 |  2   |
# | 0.03283584117889404  |  3   |
# | 0.03007519245147705  |  4   |
# | 0.02713179588317871  |  5   |
# | 0.02517986297607422  |  6   |
# | 0.023715436458587646 |  7   |
# | 0.020325183868408203 |  8   |
# | 0.020202040672302246 |  9   |
# | 0.019685029983520508 |  10  |
# +----------------------+------+
# [10 rows x 4 columns]

# %%
# %matplotlib inline
model_performance = turicreate.recommender.util.compare_models(test_data,[popularity_model,personalized_model],user_sample=0.05)
# Out:
# compare_models: using 2931 users to estimate model performance
# PROGRESS: Evaluate model M0
# recommendations finished on 1000/2931 queries. users per second: 3006.04
# recommendations finished on 2000/2931 queries. users per second: 2904.65
# WARNING:root:Model trained without a target. Skipping RMSE computation.
# Precision and recall summary statistics by cutoff
# +--------+----------------------+----------------------+
# | cutoff |    mean_precision    |     mean_recall      |
# +--------+----------------------+----------------------+
# |   1    | 0.020129648584100972 | 0.004846797502887577 |
# |   2    | 0.021494370522006145 | 0.012062768536668232 |
# |   3    | 0.02160809735016494  | 0.01722216711981301  |
# |   4    | 0.02047082906857728  | 0.02166889840891892  |
# |   5    | 0.018491982258614845 | 0.02459598951410621  |
# |   6    | 0.017400204708290668 | 0.02796338674025472  |
# |   7    | 0.01657162353170543  | 0.030735740433795723 |
# |   8    | 0.015864892528147385 | 0.03357321627536569  |
# |   9    | 0.015542666515030909 | 0.03665117626223057  |
# |   10   | 0.014977823268509077 |  0.0390334740130032  |
# +--------+----------------------+----------------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
# recommendations finished on 1000/2931 queries. users per second: 2601.99
# recommendations finished on 2000/2931 queries. users per second: 2630.31
# WARNING:root:Model trained without a target. Skipping RMSE computation.
# Precision and recall summary statistics by cutoff
# +--------+----------------------+----------------------+
# | cutoff |    mean_precision    |     mean_recall      |
# +--------+----------------------+----------------------+
# |   1    | 0.09962470146707617  | 0.03408902121798739  |
# |   2    | 0.08375980893892868  | 0.051692029302059975 |
# |   3    | 0.07380871147503708  | 0.06619293364431542  |
# |   4    | 0.06601842374616175  | 0.07652652514474408  |
# |   5    | 0.059570112589559805 |  0.0846847956622777  |
# |   6    | 0.05527123848515865  | 0.09317748951832888  |
# |   7    | 0.05161573329434124  | 0.10020254111861071  |
# |   8    | 0.047978505629477995 | 0.10622354350604087  |
# |   9    | 0.04496000606543088  | 0.11092021913413931  |
# |   10   | 0.04264756055953595  | 0.11686364736518272  |
# +--------+----------------------+----------------------+
# [10 rows x 3 columns]
